# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/benchmarkVecMapDelete.csv')

# %%
df
# Out:
#       Sz Container    TimeNs
# 0     10       Vec   34.6348
# 1     10       Map  212.9880
# 2     11       Vec   55.2132
# 3     11       Map  163.2120
# 4     12       Vec   50.3493
# ..   ...       ...       ...
# 377  198       Map  211.1850
# 378  199       Vec   50.4574
# 379  199       Map  192.7930
# 380  200       Vec   49.0394
# 381  200       Map  190.1070
#
# [382 rows x 3 columns]

# %%
ax = None
for container in df['Container'].unique():
    subset = df[df['Container'] == container]
    ax = subset.plot(x='TimeNs', y='Sz', label=container, title='Sz vs Time for each Container', ax=ax)

plt.legend()
plt.show()
